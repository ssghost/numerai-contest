# %%
import os

dataset_root = "/kaggle/input/datasets/username/numerai-data-v52"
cus_feat_path = "/kaggle/input/datasets/username/numerai-custom-features/custom_features.json"
print(f"{dataset_root}")
print(f"{os.listdir(dataset_root)}, {cus_feat_path}")
# Out:
# /kaggle/input/datasets/shuangsong/numerai-data-v52
# ['features.json', 'train.parquet', 'validation.parquet'], /kaggle/input/datasets/shuangsong/numerai-custom-features/custom_features.json

# %%
import pandas as pd
import numpy as np
import gc
import torch

def load_optimized(path, features, flag, tv_ratio=0.8):
    df = pd.read_parquet(path, columns=['target', 'era'] + features, engine='pyarrow')
    df = df.iloc[::4]

    if df['era'].dtype == 'object':
        df['era'] = df['era'].str.replace('era', '').astype(int)
    else:
        df['era'] = df['era'].astype(int)

    df = df.astype('float32')
    unique_eras = np.sort(df['era'].unique())
    ckpt_era = unique_eras[int(len(unique_eras) * tv_ratio)]

    if flag == "train":
        mask = df['era'] <= ckpt_era
    elif flag == "val":
        mask = df['era'] > ckpt_era
        
    X = torch.from_numpy(df.loc[mask, features].values).float()
    y = torch.from_numpy(df.loc[mask, 'target'].values).float()
    
    del df
    gc.collect() 
    
    return X, y

# %%
import torch
import torch.nn as nn

class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.fc1 = nn.Linear(channels, channels // reduction)
        self.relu = nn.ReLU() 
        self.fc2 = nn.Linear(channels // reduction, channels)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        weight = self.fc1(x)
        weight = self.relu(weight)
        weight = self.fc2(weight)
        weight = self.sigmoid(weight)
        return x * weight
        
class ResBlock(nn.Module):
    def __init__(self, size, dropout_rate=0.5):
        super(ResBlock, self).__init__()
        self.l = nn.Linear(size, size)
        self.bn = nn.BatchNorm1d(size)
        self.activation = nn.SiLU()
        self.se = SEBlock(size)
        self.dropout = nn.Dropout(dropout_rate)

    def forward(self, x):
        identity = x
        out = self.l(x)
        out = self.bn(out)
        out = self.activation(out)
        out = self.se(out)
        out = self.dropout(out)
        return out + identity

class NumeraiNet(nn.Module):
    def __init__(self, input_size):
        super(NumeraiNet, self).__init__()
        self.input_dropout = nn.Dropout(0.1)
        self.initial_layer = nn.Sequential(
            nn.Linear(input_size, 256),
            nn.BatchNorm1d(256),
            nn.SiLU()
        )
        self.res_blocks = nn.Sequential(
            ResBlock(256, 0.5),
            ResBlock(256, 0.5)
        )
        self.output_layer = nn.Linear(256, 1)

    def forward(self, x):
        x = self.input_dropout(x)
        x = self.initial_layer(x)
        x = self.res_blocks(x)
        return torch.sigmoid(self.output_layer(x))

# %%
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import numpy as np
import json
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Loaded device:{device}")
TRAIN_PATH = os.path.join(dataset_root, "train.parquet")
VAL_PATH = os.path.join(dataset_root, "validation.parquet")
FEAT_PATH = os.path.join(dataset_root, "features.json")

with open(cus_feat_path, 'r') as f:
    custom_data = json.load(f)
    features = custom_data['feature_sets']['custom_features']

X, y = load_optimized(TRAIN_PATH, features, flag='train')
X_val, y_val = load_optimized(VAL_PATH, features, flag='val')

dataset = TensorDataset(X, y)
loader = DataLoader(dataset, batch_size=4096, shuffle=True)
model = NumeraiNet(len(features)).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-5)
criterion = nn.MSELoss()
scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2, eta_min=1e-6)
epochs = 100
best_corr = -1.0
CURRENT_SAVE_PATH = None

for epoch in range(epochs):
    model.train()
    total_loss = 0
    for data, target in loader:
        data, target = data.to(device), target.to(device).reshape(-1,1)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        total_loss += loss.item()

    model.eval()
    with torch.no_grad():
        preds_list = []
        val_loader = DataLoader(TensorDataset(X_val), batch_size=8192)
        for val_batch in val_loader:
            batch_data = val_batch[0].to(device)
            p = model(batch_data).cpu().detach().flatten().tolist()
            preds_list.extend(p)
    torch.cuda.empty_cache()
    actual_y = y_val.cpu().numpy().flatten()
    predicted_y = np.array(preds_list).flatten()

    corr = pd.Series(actual_y).corr(pd.Series(predicted_y), method='spearman')
    scheduler.step()
    print(f"Epoch {epoch+1:2d}/{epochs} | Loss: {total_loss/len(loader):.5f} | Val CORR: {corr:.4f}")

    if corr > best_corr:
        if CURRENT_SAVE_PATH is not None and os.path.exists(CURRENT_SAVE_PATH):
            os.remove(CURRENT_SAVE_PATH)
        best_corr = corr
        corr_suffix = f"{int(corr * 10000):04d}"
        CURRENT_SAVE_PATH = f"/kaggle/working/model_custom_{corr_suffix}.pth"
        torch.save(model.state_dict(), CURRENT_SAVE_PATH)
        print(f"New optimized model saved at: {CURRENT_SAVE_PATH} (CORR: {best_corr:.4f})")
# Out:
# Loaded device:cuda
# Epoch  1/100 | Loss: 0.05626 | Val CORR: -0.0011
# New optimized model saved at: /kaggle/working/model_custom_-011.pth (CORR: -0.0011)
# Epoch  2/100 | Loss: 0.05215 | Val CORR: -0.0022
# Epoch  3/100 | Loss: 0.05157 | Val CORR: -0.0013
# Epoch  4/100 | Loss: 0.05121 | Val CORR: -0.0022
# Epoch  5/100 | Loss: 0.05097 | Val CORR: -0.0011
# New optimized model saved at: /kaggle/working/model_custom_-011.pth (CORR: -0.0011)
# Epoch  6/100 | Loss: 0.05086 | Val CORR: -0.0009
# New optimized model saved at: /kaggle/working/model_custom_-009.pth (CORR: -0.0009)
# Epoch  7/100 | Loss: 0.05082 | Val CORR: -0.0010
# Epoch  8/100 | Loss: 0.05074 | Val CORR: 0.0003
# New optimized model saved at: /kaggle/working/model_custom_0003.pth (CORR: 0.0003)
# Epoch  9/100 | Loss: 0.05065 | Val CORR: 0.0007
# New optimized model saved at: /kaggle/working/model_custom_0006.pth (CORR: 0.0007)
# Epoch 10/100 | Loss: 0.05061 | Val CORR: 0.0009
# New optimized model saved at: /kaggle/working/model_custom_0008.pth (CORR: 0.0009)
# Epoch 11/100 | Loss: 0.05059 | Val CORR: 0.0002
# Epoch 12/100 | Loss: 0.05044 | Val CORR: 0.0033
# New optimized model saved at: /kaggle/working/model_custom_0032.pth (CORR: 0.0033)
# Epoch 13/100 | Loss: 0.05031 | Val CORR: 0.0034
# New optimized model saved at: /kaggle/working/model_custom_0033.pth (CORR: 0.0034)
# Epoch 14/100 | Loss: 0.05023 | Val CORR: 0.0019
# Epoch 15/100 | Loss: 0.05011 | Val CORR: 0.0032
# Epoch 16/100 | Loss: 0.05002 | Val CORR: 0.0032
# Epoch 17/100 | Loss: 0.04999 | Val CORR: 0.0037
# New optimized model saved at: /kaggle/working/model_custom_0037.pth (CORR: 0.0037)
# Epoch 18/100 | Loss: 0.04993 | Val CORR: 0.0037
# Epoch 19/100 | Loss: 0.04987 | Val CORR: 0.0048
# New optimized model saved at: /kaggle/working/model_custom_0047.pth (CORR: 0.0048)
# Epoch 20/100 | Loss: 0.04994 | Val CORR: 0.0050
# New optimized model saved at: /kaggle/working/model_custom_0049.pth (CORR: 0.0050)
# Epoch 21/100 | Loss: 0.04983 | Val CORR: 0.0051
# New optimized model saved at: /kaggle/working/model_custom_0051.pth (CORR: 0.0051)
# Epoch 22/100 | Loss: 0.04981 | Val CORR: 0.0046
# Epoch 23/100 | Loss: 0.04981 | Val CORR: 0.0054
# New optimized model saved at: /kaggle/working/model_custom_0054.pth (CORR: 0.0054)
# Epoch 24/100 | Loss: 0.04981 | Val CORR: 0.0048
# Epoch 25/100 | Loss: 0.04973 | Val CORR: 0.0047
# Epoch 26/100 | Loss: 0.04979 | Val CORR: 0.0046
# Epoch 27/100 | Loss: 0.04985 | Val CORR: 0.0049
# Epoch 28/100 | Loss: 0.04976 | Val CORR: 0.0048
# Epoch 29/100 | Loss: 0.04976 | Val CORR: 0.0049
# Epoch 30/100 | Loss: 0.04976 | Val CORR: 0.0049
# Epoch 31/100 | Loss: 0.04978 | Val CORR: 0.0047
# Epoch 32/100 | Loss: 0.04966 | Val CORR: 0.0049
# Epoch 33/100 | Loss: 0.04972 | Val CORR: 0.0036
# Epoch 34/100 | Loss: 0.04968 | Val CORR: 0.0030
# Epoch 35/100 | Loss: 0.04960 | Val CORR: 0.0053
# Epoch 36/100 | Loss: 0.04962 | Val CORR: 0.0059
# New optimized model saved at: /kaggle/working/model_custom_0059.pth (CORR: 0.0059)
# Epoch 37/100 | Loss: 0.04952 | Val CORR: 0.0059
# Epoch 38/100 | Loss: 0.04959 | Val CORR: 0.0052
# Epoch 39/100 | Loss: 0.04956 | Val CORR: 0.0065
# New optimized model saved at: /kaggle/working/model_custom_0065.pth (CORR: 0.0065)
# Epoch 40/100 | Loss: 0.04951 | Val CORR: 0.0052
# Epoch 41/100 | Loss: 0.04953 | Val CORR: 0.0038
# Epoch 42/100 | Loss: 0.04947 | Val CORR: 0.0046
# Epoch 43/100 | Loss: 0.04936 | Val CORR: 0.0036
# Epoch 44/100 | Loss: 0.04933 | Val CORR: 0.0045
# Epoch 45/100 | Loss: 0.04936 | Val CORR: 0.0043
# Epoch 46/100 | Loss: 0.04935 | Val CORR: 0.0065
# Epoch 47/100 | Loss: 0.04931 | Val CORR: 0.0052
# Epoch 48/100 | Loss: 0.04925 | Val CORR: 0.0036
# Epoch 49/100 | Loss: 0.04924 | Val CORR: 0.0045
# Epoch 50/100 | Loss: 0.04923 | Val CORR: 0.0034
# Epoch 51/100 | Loss: 0.04916 | Val CORR: 0.0047
# Epoch 52/100 | Loss: 0.04917 | Val CORR: 0.0047
# Epoch 53/100 | Loss: 0.04912 | Val CORR: 0.0044
# Epoch 54/100 | Loss: 0.04914 | Val CORR: 0.0037
# Epoch 55/100 | Loss: 0.04908 | Val CORR: 0.0044
# Epoch 56/100 | Loss: 0.04901 | Val CORR: 0.0050
# Epoch 57/100 | Loss: 0.04906 | Val CORR: 0.0046
# Epoch 58/100 | Loss: 0.04904 | Val CORR: 0.0035
# Epoch 59/100 | Loss: 0.04903 | Val CORR: 0.0042
# Epoch 60/100 | Loss: 0.04906 | Val CORR: 0.0038
# Epoch 61/100 | Loss: 0.04904 | Val CORR: 0.0041
# Epoch 62/100 | Loss: 0.04893 | Val CORR: 0.0043
# Epoch 63/100 | Loss: 0.04904 | Val CORR: 0.0045
# Epoch 64/100 | Loss: 0.04901 | Val CORR: 0.0045
# Epoch 65/100 | Loss: 0.04891 | Val CORR: 0.0045
# Epoch 66/100 | Loss: 0.04894 | Val CORR: 0.0044
# Epoch 67/100 | Loss: 0.04903 | Val CORR: 0.0046
# Epoch 68/100 | Loss: 0.04897 | Val CORR: 0.0045
# Epoch 69/100 | Loss: 0.04896 | Val CORR: 0.0046
# Epoch 70/100 | Loss: 0.04896 | Val CORR: 0.0045
# Epoch 71/100 | Loss: 0.04907 | Val CORR: 0.0040
# Epoch 72/100 | Loss: 0.04906 | Val CORR: 0.0052
# Epoch 73/100 | Loss: 0.04906 | Val CORR: 0.0052
# Epoch 74/100 | Loss: 0.04896 | Val CORR: 0.0067
# New optimized model saved at: /kaggle/working/model_custom_0066.pth (CORR: 0.0067)
# Epoch 75/100 | Loss: 0.04903 | Val CORR: 0.0070
# New optimized model saved at: /kaggle/working/model_custom_0070.pth (CORR: 0.0070)
# Epoch 76/100 | Loss: 0.04893 | Val CORR: 0.0069
# Epoch 77/100 | Loss: 0.04889 | Val CORR: 0.0056
# Epoch 78/100 | Loss: 0.04888 | Val CORR: 0.0046
# Epoch 79/100 | Loss: 0.04885 | Val CORR: 0.0050
# Epoch 80/100 | Loss: 0.04884 | Val CORR: 0.0052
# Epoch 81/100 | Loss: 0.04877 | Val CORR: 0.0037
# Epoch 82/100 | Loss: 0.04878 | Val CORR: 0.0063
# Epoch 83/100 | Loss: 0.04879 | Val CORR: 0.0057
# Epoch 84/100 | Loss: 0.04877 | Val CORR: 0.0058
# Epoch 85/100 | Loss: 0.04872 | Val CORR: 0.0064
# Epoch 86/100 | Loss: 0.04874 | Val CORR: 0.0035
# Epoch 87/100 | Loss: 0.04862 | Val CORR: 0.0049
# Epoch 88/100 | Loss: 0.04860 | Val CORR: 0.0067
# Epoch 89/100 | Loss: 0.04861 | Val CORR: 0.0071
# New optimized model saved at: /kaggle/working/model_custom_0071.pth (CORR: 0.0071)
# Epoch 90/100 | Loss: 0.04855 | Val CORR: 0.0056
# Epoch 91/100 | Loss: 0.04855 | Val CORR: 0.0077
# New optimized model saved at: /kaggle/working/model_custom_0076.pth (CORR: 0.0077)
# Epoch 92/100 | Loss: 0.04852 | Val CORR: 0.0048
# Epoch 93/100 | Loss: 0.04848 | Val CORR: 0.0066
# Epoch 94/100 | Loss: 0.04847 | Val CORR: 0.0020
# Epoch 95/100 | Loss: 0.04846 | Val CORR: 0.0067
# Epoch 96/100 | Loss: 0.04850 | Val CORR: 0.0039
# Epoch 97/100 | Loss: 0.04842 | Val CORR: 0.0057
# Epoch 98/100 | Loss: 0.04841 | Val CORR: 0.0073
# Epoch 99/100 | Loss: 0.04835 | Val CORR: 0.0052
# Epoch 100/100 | Loss: 0.04843 | Val CORR: 0.0058
